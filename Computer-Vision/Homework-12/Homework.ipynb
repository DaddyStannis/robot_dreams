# %% [markdown]
# ### Binary Traffic Sign Classification
#
# This is our first notebook on neural networks. We will start by building a simple neural network that will help us to classify two types of traffic signs. The signs used in this lesson are a processed subset from the famous German Traffic Sign Recognition Database (GTSRB) that can be downloaded [here]().

# %%
import os
import cv2
from time import time
import numpy as np
from sklearn.utils import shuffle

from matplotlib import pyplot as plt
plt.rcParams['figure.figsize'] = [15, 6]

# %% [markdown]
# #### Data Loading
#
# Let's now load the data to see what we are dealing with.

# %%
folder = 'data'

# Load traffic sign class 0
fnames_0 = os.listdir(os.path.join(folder, 'class_id_0'))
images_0 = [cv2.imread(os.path.join(folder, 'class_id_0', f), cv2.IMREAD_UNCHANGED) for f in fnames_0]
labels_0 = [0] * len(images_0)

for cnt, idx in enumerate(np.random.randint(0, len(images_0), 10)):
    plt.subplot(2,5,cnt+1)
    plt.imshow(images_0[idx], cmap='gray', vmin=0, vmax=255)
    plt.title(labels_0[idx]), plt.axis(False)

# %%
# Load traffic sign class 1
fnames_1 = os.listdir(os.path.join(folder, 'class_id_1'))
images_1 = [cv2.imread(os.path.join(folder, 'class_id_1', f), cv2.IMREAD_UNCHANGED) for f in fnames_1]
labels_1 = [1] * len(images_1)

for cnt, idx in enumerate(np.random.randint(0, len(images_1), 10)):
    plt.subplot(2,5,cnt+1)
    plt.imshow(images_1[idx], cmap='gray', vmin=0, vmax=255)
    plt.title(labels_1[idx]), plt.axis(False)

# %%
print('Num samples class_0', len(images_0))
print('Num samples class_1', len(images_1))
# Out:
# Num samples class_0 2220
# Num samples class_1 2250

# %% [markdown]
# #### Prepare Input Data
#
# To train our neural network model, we have to prepare the data to the format the the model actually expects. In our case, this will be numpy arrays.

# %%
# Put both classes together and shuffle the data
images = images_0 + images_1
labels = labels_0 + labels_1
images, labels = shuffle(images, labels)

images = np.array(images)
labels = np.array(labels)

print('Images', images.shape)
print('Labels', labels.shape)
# Out:
# Images (4470, 28, 28)
# Labels (4470,)

# %% [markdown]
# But now we have a problem. We cannot just feed the image to a neuron since the neuron inputs are flat (one dimensional). On the other hand, the images are 2D matrices. Therefore, we need to "flatten" the images to a one dimensional vector of pixels.

# %%
start = time()
pixels = []
for image in images:
    pixels_ = []
    for r in range(image.shape[0]):
        for c in range(image.shape[1]):
            pixels_.append(image[r,c])
    pixels.append(pixels_)
    
pixels = np.array(pixels)/255
stop = time()

print('Shape', pixels.shape)
print('Elapsed time', stop - start)
# Out:
# Shape (4470, 784)
# Elapsed time 0.8402566909790039

# %% [markdown]
# Or, you know, just let make use of our friend numpy :-)

# %%
start = time()
pixels = np.array([image.flatten() for image in images])/255
stop = time()

print('Shape', pixels.shape)
print('Elapsed time', stop - start)
# Out:
# Shape (4470, 784)
# Elapsed time 0.0603947639465332

# %% [markdown]
# Before the training, let's again have a look at some raqndom samples from our dataset.

# %%
for cnt, idx in enumerate(np.random.randint(0, len(images), 10)):    
    plt.subplot(2,5,cnt+1)
    plt.imshow(images[idx], cmap='gray', vmin=0, vmax=255)
    plt.title(labels[idx])

# %% [markdown]
# #### Building the Neural Network
#
# Let's now build our first (and yes, very simple) neural network using Tensorflow. For that, we will need a couple of new imports.

# %%
import tensorflow as tf
from tensorflow.keras import Model
from tensorflow.keras.layers import Dense, Input

# %% [markdown]
# The following netowork will consist of only one single neuron. It is a very tiny network (not even a network, strictly speaking :-) ) and yet it can be quite powerful.

# %%
inputs = Input(shape=(pixels.shape[1],))
hidden = Dense(64, activation="relu")(inputs)
outputs = Dense(1, activation="linear")(hidden)
model = Model(inputs, outputs)

model.summary()
# Out:
# Model: "functional_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_4 (InputLayer)      │ (None, 784)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 64)             │        50,240 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 50,305 (196.50 KB)
#  Trainable params: 50,305 (196.50 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
tf.keras.utils.plot_model(model, to_file="model.png", show_shapes=True, show_layer_names=True)
# Out:
# You must install pydot (`pip install pydot`) for `plot_model` to work.

# %% [markdown]
# Before starting the training, we have to compile the model. During the compilation, we indicate what optimizer we want to use and what loss should be applied for the minimization process.

# %%
model.compile(optimizer ='adam', loss = 'mean_squared_error')

# %% [markdown]
# And let's train :-)

# %%
history = model.fit(pixels, labels, epochs=100, batch_size=32)
# Out:
# Epoch 1/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0662
# Epoch 2/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0692
# Epoch 3/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0621
# Epoch 4/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0614
# Epoch 5/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0588
# Epoch 6/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0607
# Epoch 7/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0609
# Epoch 8/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0538
# Epoch 9/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0542
# Epoch 10/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0504
# Epoch 11/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0546
# Epoch 12/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0503
# Epoch 13/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0519
# Epoch 14/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0520
# Epoch 15/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0556
# Epoch 16/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0451
# Epoch 17/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0467
# Epoch 18/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0461
# Epoch 19/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0465
# Epoch 20/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0441
# Epoch 21/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0390
# Epoch 22/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0459
# Epoch 23/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0402
# Epoch 24/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0418
# Epoch 25/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0414
# Epoch 26/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0385
# Epoch 27/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0394
# Epoch 28/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0414
# Epoch 29/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0370
# Epoch 30/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0400
# Epoch 31/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0360
# Epoch 32/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0370
# Epoch 33/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0340
# Epoch 34/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0379
# Epoch 35/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0334
# Epoch 36/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0361
# Epoch 37/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0383
# Epoch 38/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0320
# Epoch 39/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0313
# Epoch 40/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0311
# Epoch 41/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0361
# Epoch 42/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0316
# Epoch 43/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0319
# Epoch 44/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0302
# Epoch 45/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0332
# Epoch 46/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0304
# Epoch 47/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0282
# Epoch 48/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0344
# Epoch 49/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0326
# Epoch 50/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0299
# Epoch 51/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0285
# Epoch 52/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0277
# Epoch 53/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0289
# Epoch 54/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0267
# Epoch 55/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0261
# Epoch 56/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0272
# Epoch 57/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0264
# Epoch 58/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0282
# Epoch 59/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0262
# Epoch 60/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0257
# Epoch 61/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0263
# Epoch 62/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0285
# Epoch 63/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0239
# Epoch 64/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0260
# Epoch 65/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0260
# Epoch 66/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0247
# Epoch 67/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0244
# Epoch 68/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0240
# Epoch 69/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0259
# Epoch 70/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0270
# Epoch 71/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0241
# Epoch 72/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0233
# Epoch 73/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0232
# Epoch 74/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0265
# Epoch 75/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0236
# Epoch 76/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0262
# Epoch 77/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0232
# Epoch 78/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0250
# Epoch 79/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0218
# Epoch 80/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0230
# Epoch 81/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0233
# Epoch 82/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0243
# Epoch 83/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0248
# Epoch 84/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0196
# Epoch 85/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0256
# Epoch 86/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0217
# Epoch 87/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0214
# Epoch 88/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0221
# Epoch 89/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0208
# Epoch 90/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0241
# Epoch 91/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0204
# Epoch 92/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0196
# Epoch 93/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0197
# Epoch 94/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0188
# Epoch 95/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0246
# Epoch 96/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0188
# Epoch 97/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0221
# Epoch 98/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0174
# Epoch 99/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0179
# Epoch 100/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0215

# %%
# Plot training history
h = history.history
epochs = range(len(h['loss']))
plt.plot(epochs, h['loss'], '.-'), plt.grid(True)
plt.xlabel('epoch'), plt.ylabel('loss')
# Out:
# (Text(0.5, 0, 'epoch'), Text(0, 0.5, 'loss'))

# %%
# Let's also have a looks at the learnt weights
plt.plot(model.layers[1].weights[0].numpy(), '.-'), plt.grid(True)
print(model.layers[1].weights[1].numpy(), model.layers[1].bias.numpy())
# Out:
# [-6.0045747e-03  4.2658621e-01  5.5522287e-01  5.5980569e-01
#   4.2419478e-02 -5.2773152e-03 -5.3155455e-03  3.4994090e-01
#  -5.5546290e-03 -1.2959008e-02 -6.5464103e-03 -6.0028057e-03
#  -3.1853430e-03  1.9914423e-01 -6.0032811e-03 -9.5088650e-03
#  -6.0039326e-03 -1.2563918e-02  2.1779381e-01  3.4223360e-01
#   9.1005795e-02 -9.3120877e-03  4.9874526e-01 -6.4195222e-03
#   6.3143218e-01  2.3272234e-01 -3.2497018e-03  2.0933485e-01
#   2.8396723e-01 -8.3046136e-03  3.8888836e-01 -7.3327222e-03
#  -1.0034969e-02  6.1060750e-01 -6.0001081e-03 -3.8709557e-03
#   5.5576038e-01 -7.4305693e-03 -7.9117035e-03 -1.9837806e-02
#   4.0478534e-03  0.0000000e+00  7.4935764e-02 -8.1455819e-03
#   1.7251514e-02  1.2441405e-01  2.4642809e-01 -8.6590732e-03
#  -4.1195815e-03  1.8662478e-01 -5.1051984e-03  5.8583325e-01
#  -6.0043246e-03  6.2791336e-01 -8.6606815e-03 -3.8463038e-03
#  -5.9989938e-03  3.7414458e-04  5.9671151e-03 -3.8715198e-03
#  -5.3576599e-03 -3.3030028e-03 -7.2902767e-03 -5.1588183e-03] [-6.0045747e-03  4.2658621e-01  5.5522287e-01  5.5980569e-01
#   4.2419478e-02 -5.2773152e-03 -5.3155455e-03  3.4994090e-01
#  -5.5546290e-03 -1.2959008e-02 -6.5464103e-03 -6.0028057e-03
#  -3.1853430e-03  1.9914423e-01 -6.0032811e-03 -9.5088650e-03
#  -6.0039326e-03 -1.2563918e-02  2.1779381e-01  3.4223360e-01
#   9.1005795e-02 -9.3120877e-03  4.9874526e-01 -6.4195222e-03
#   6.3143218e-01  2.3272234e-01 -3.2497018e-03  2.0933485e-01
#   2.8396723e-01 -8.3046136e-03  3.8888836e-01 -7.3327222e-03
#  -1.0034969e-02  6.1060750e-01 -6.0001081e-03 -3.8709557e-03
#   5.5576038e-01 -7.4305693e-03 -7.9117035e-03 -1.9837806e-02
#   4.0478534e-03  0.0000000e+00  7.4935764e-02 -8.1455819e-03
#   1.7251514e-02  1.2441405e-01  2.4642809e-01 -8.6590732e-03
#  -4.1195815e-03  1.8662478e-01 -5.1051984e-03  5.8583325e-01
#  -6.0043246e-03  6.2791336e-01 -8.6606815e-03 -3.8463038e-03
#  -5.9989938e-03  3.7414458e-04  5.9671151e-03 -3.8715198e-03
#  -5.3576599e-03 -3.3030028e-03 -7.2902767e-03 -5.1588183e-03]

# %% [markdown]
# #### Performance Evaluation
#
# Once our model is trained, we will can run it on our images to see how it performs (inference).

# %%
idx = 50
pred = model.predict(pixels[idx:idx+1, ...])
print(pred, labels[idx])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# [[0.00478382]] 0

# %%
# Run it on the entire dataset
predictions = model.predict(pixels).squeeze()
predictions = predictions > 0.5
# Out:
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step

# %%
correct = 0
for prediction, label in zip(predictions, labels):
    if prediction == label:
        correct = correct + 1

print('Accuracy', correct/len(labels))
# Out:
# Accuracy 0.9975391498881432

# %%
for cnt, idx in enumerate(np.random.randint(0, len(images), 10)): 
    plt.subplot(2,5,cnt+1), plt.imshow(images[idx], cmap='gray', vmin=0, vmax=255)
    plt.title('Label: ' + str(labels[idx]) + ' | Prediction: ' + str(predictions[idx]))
    plt.axis(False)

# %% [markdown]
# ### Answers
#
# * 2220 for class 0 images and 2250 for class 1 images
# * 0.9
# * I added 1 neuron and the number of epochs to 100, which gave me an accuracy of 0.99
